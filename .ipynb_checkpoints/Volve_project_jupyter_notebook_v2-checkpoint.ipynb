# %%
## Importing the necessary packages and setting up the notebook

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from pathlib import Path
import os
import matplotlib as mpl
import sklearn
import seaborn as sns
import tensorflow as tf
import scipy

mpl.rcParams["axes.grid"] = False
# %matplotlib inline

# %%
dataset_path = Path(os.getcwd()) / "production_data" / "volve_production_data_working.xlsx"

# %%
## Installing openpyxl library to read the excel file in pandas
# pip install openpyxl

# %%
prod_df = pd.read_excel(dataset_path, parse_dates = [0])

# %%
prod_df.head()
# Out:
#      DATEPRD  NPD_WELL_BORE_CODE  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# 0 2014-04-07                7405            0.0                0.00000
# 1 2014-04-08                7405            0.0                    NaN
# 2 2014-04-09                7405            0.0                    NaN
# 3 2014-04-10                7405            0.0                    NaN
# 4 2014-04-11                7405            0.0              310.37614
#
#    AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  AVG_ANNULUS_PRESS  \
# 0                   0.00000        0.00000                0.0
# 1                       NaN            NaN                0.0
# 2                       NaN            NaN                0.0
# 3                       NaN            NaN                0.0
# 4                  96.87589      277.27826                0.0
#
#    AVG_CHOKE_SIZE_P AVG_CHOKE_UOM  AVG_WHP_P  AVG_WHT_P  DP_CHOKE_SIZE  \
# 0          0.000000             %    0.00000    0.00000        0.00000
# 1          1.003059             %    0.00000    0.00000        0.00000
# 2          0.979008             %    0.00000    0.00000        0.00000
# 3          0.545759             %    0.00000    0.00000        0.00000
# 4          1.215987             %   33.09788   10.47992       33.07195
#
#    BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL  BORE_WI_VOL   FLOW_KIND
# 0           0.0           0.0           0.0          NaN  production
# 1           0.0           0.0           0.0          NaN  production
# 2           0.0           0.0           0.0          NaN  production
# 3           0.0           0.0           0.0          NaN  production
# 4           0.0           0.0           0.0          NaN  production

# %%
prod_df.describe()
# Out:
#        NPD_WELL_BORE_CODE  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# count         9161.000000    9161.000000            8980.000000
# mean          6034.808645      20.168721             181.803869
# std            824.532027       8.293401             109.712363
# min           5351.000000       0.000000               0.000000
# 25%           5351.000000      24.000000               0.000000
# 50%           5599.000000      24.000000             232.896939
# 75%           7078.000000      24.000000             255.401455
# max           7405.000000      25.000000             397.588550
#
#        AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  AVG_ANNULUS_PRESS  \
# count               8980.000000    8980.000000        7890.000000
# mean                  77.162969     154.028787          14.856100
# std                   45.657948      76.752373           8.406822
# min                    0.000000       0.000000           0.000000
# 25%                    0.000000      83.665361          10.841437
# 50%                  103.186689     175.588861          16.308598
# 75%                  106.276591     204.319964          21.306125
# max                  108.502178     345.906770          30.019828
#
#        AVG_CHOKE_SIZE_P    AVG_WHP_P    AVG_WHT_P  DP_CHOKE_SIZE  \
# count       8919.000000  9155.000000  9146.000000    9155.000000
# mean          55.168533    45.377811    67.728440      19.170492
# std           36.692924    24.752631    27.719028      22.580005
# min            0.000000     0.000000     0.000000       0.000000
# 25%           18.952989    31.148062    56.577834       3.356379
# 50%           52.096877    37.933620    80.071250       9.566033
# 75%           99.924288    57.101268    88.062202      26.967948
# max          100.000000   137.311030    93.509584     125.718570
#
#        BORE_OIL_VOL   BORE_GAS_VOL  BORE_WAT_VOL  BORE_WI_VOL
# count   9161.000000    9161.000000   9161.000000         15.0
# mean    1095.631548  161049.059703   1672.151332          0.0
# std     1323.538151  188136.410434   1706.982853          0.0
# min        0.000000       0.000000   -457.840000          0.0
# 25%      190.690000   29430.590000     19.870000          0.0
# 50%      557.550000   87749.660000   1097.790000          0.0
# 75%     1345.200000  202482.300000   3260.950000          0.0
# max     5901.840000  851131.520000   8019.740000          0.0

# %%
prod_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9161 entries, 0 to 9160
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   9161 non-null   datetime64[ns]
#  1   NPD_WELL_BORE_CODE        9161 non-null   int64
#  2   ON_STREAM_HRS             9161 non-null   float64
#  3   AVG_DOWNHOLE_PRESSURE     8980 non-null   float64
#  4   AVG_DOWNHOLE_TEMPERATURE  8980 non-null   float64
#  5   AVG_DP_TUBING             8980 non-null   float64
#  6   AVG_ANNULUS_PRESS         7890 non-null   float64
#  7   AVG_CHOKE_SIZE_P          8919 non-null   float64
#  8   AVG_CHOKE_UOM             9161 non-null   object
#  9   AVG_WHP_P                 9155 non-null   float64
#  10  AVG_WHT_P                 9146 non-null   float64
#  11  DP_CHOKE_SIZE             9155 non-null   float64
#  12  BORE_OIL_VOL              9161 non-null   float64
#  13  BORE_GAS_VOL              9161 non-null   float64
#  14  BORE_WAT_VOL              9161 non-null   float64
#  15  BORE_WI_VOL               15 non-null     float64
#  16  FLOW_KIND                 9161 non-null   object
# dtypes: datetime64[ns](1), float64(13), int64(1), object(2)
# memory usage: 1.2+ MB

# %%
prod_df.drop(["AVG_CHOKE_UOM", "FLOW_KIND", "AVG_DP_TUBING", "BORE_WI_VOL", "AVG_ANNULUS_PRESS"], axis = 1, inplace = True)

# %%
## Function to break the dataset into separate datasets so that each dataset only contains a single well data
## Returns a dictionary with key as well id and values as the corresponding dataset for that well

def wellwise_break(df):
    wells = df.NPD_WELL_BORE_CODE.unique()
    df_wells = {}
    for well in wells:
        df_wells[well] = df[df["NPD_WELL_BORE_CODE"] == well].reset_index(drop = True)
        df_wells[well] = df_wells[well].drop(["NPD_WELL_BORE_CODE"], axis = 1)
    return df_wells

# %%
well_df_dict = wellwise_break(prod_df)

# %%
list(well_df_dict.keys())
# Out:
# [7405, 7078, 5599, 5769, 7289, 5351]

# %%
# A utility function to save the figures in the "figures" folder inside the working directory

def fig_save(fig, name, path = 'C:\\Users\\spect\\OneDrive\\Desktop\\ML_conda_projects\\spectre_lab\\volve_dataset_project\\figures'):
    fig.savefig(os.path.join(path, name + ".png"), dpi = 1000, bbox_inches = "tight")
    print(os.path.join(path, name + ".png"))

# %%
# Visualizing the production profile of all the wells...

for (well, df) in zip(well_df_dict.keys(), well_df_dict.values()):
    df_nf_dates = df[df.ON_STREAM_HRS == 0]["DATEPRD"]
    fig, ax_1 = plt.subplots()
    ax_1 = sns.scatterplot(x = df.DATEPRD, y = df.BORE_OIL_VOL, hue = df.BORE_OIL_VOL, 
                           palette = "crest", alpha = 0.5, legend = False)
    plt.xticks(rotation = 45)
    for date in df_nf_dates:
        ax_1.axvline(date, color = "r" , linewidth = 1, alpha = 0.05)
    ax_1.set(title = f"Production profile of Well_{well}", xlabel = "Date", ylabel = "Production (m3)")
    fig_save(fig, f"Production profile of Well_{well}")
# Out:
# C:\Users\spect\OneDrive\Desktop\ML_conda_projects\spectre_lab\volve_dataset_project\figures\Production profile of Well_7405.png
# C:\Users\spect\OneDrive\Desktop\ML_conda_projects\spectre_lab\volve_dataset_project\figures\Production profile of Well_7078.png
# C:\Users\spect\OneDrive\Desktop\ML_conda_projects\spectre_lab\volve_dataset_project\figures\Production profile of Well_5599.png
# C:\Users\spect\OneDrive\Desktop\ML_conda_projects\spectre_lab\volve_dataset_project\figures\Production profile of Well_5769.png
# C:\Users\spect\OneDrive\Desktop\ML_conda_projects\spectre_lab\volve_dataset_project\figures\Production profile of Well_7289.png
# C:\Users\spect\OneDrive\Desktop\ML_conda_projects\spectre_lab\volve_dataset_project\figures\Production profile of Well_5351.png

# %% [markdown]
# After cisualizing the production profiles for all the wells, we choose the well 5351 for building our model as it has:
# 1. large number of sample points taken over a long period of time, and
# 2. its production follows the typical declining production trend seen in a typical oil well

# %%
df_5351 = well_df_dict[5351].copy()

# %% [markdown]
# # Cleaning the Dataset

# %%
df_5351.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3056 entries, 0 to 3055
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   3056 non-null   datetime64[ns]
#  1   ON_STREAM_HRS             3056 non-null   float64
#  2   AVG_DOWNHOLE_PRESSURE     3050 non-null   float64
#  3   AVG_DOWNHOLE_TEMPERATURE  3050 non-null   float64
#  4   AVG_CHOKE_SIZE_P          2860 non-null   float64
#  5   AVG_WHP_P                 3056 non-null   float64
#  6   AVG_WHT_P                 3056 non-null   float64
#  7   DP_CHOKE_SIZE             3056 non-null   float64
#  8   BORE_OIL_VOL              3056 non-null   float64
#  9   BORE_GAS_VOL              3056 non-null   float64
#  10  BORE_WAT_VOL              3056 non-null   float64
# dtypes: datetime64[ns](1), float64(10)
# memory usage: 262.8 KB

# %% [markdown]
# AVG_CHOKE_SIZE_P feature has 196 nan values. We'll drop the instances with no choke size values.
#
# AVG_DOWNHOLE_PRESSURE and AVG_DOWNHOLE_TEMPERATURE both have 6 nan values within common instances. This is probably due to some sensor error as the production is non-zero in these instances. We'll also drop these instances.

# %%
## Removing Dates on which the well flowed for zero hours from the dataset
df_5351.drop(index = list(df_5351[df_5351.ON_STREAM_HRS == 0].index), axis = 0, inplace = True)

## Removing Dates on which the well produced zero m3 oil from the dataset
df_5351.drop(index = list(df_5351[df_5351.BORE_OIL_VOL == 0].index), axis = 0, inplace = True)

## Removing Instances with null values in CHOKE Size and Downhole Pressure/Temp
df_5351.drop(index = list(df_5351[pd.isna(df_5351.AVG_CHOKE_SIZE_P)].index), axis = 0, inplace = True)
df_5351.drop(index = list(df_5351[pd.isna(df_5351.AVG_DOWNHOLE_PRESSURE)].index), axis = 0, inplace = True)

df_5351.reset_index(drop = True, inplace = True)

# %%
df_5351.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2717 entries, 0 to 2716
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   2717 non-null   datetime64[ns]
#  1   ON_STREAM_HRS             2717 non-null   float64
#  2   AVG_DOWNHOLE_PRESSURE     2717 non-null   float64
#  3   AVG_DOWNHOLE_TEMPERATURE  2717 non-null   float64
#  4   AVG_CHOKE_SIZE_P          2717 non-null   float64
#  5   AVG_WHP_P                 2717 non-null   float64
#  6   AVG_WHT_P                 2717 non-null   float64
#  7   DP_CHOKE_SIZE             2717 non-null   float64
#  8   BORE_OIL_VOL              2717 non-null   float64
#  9   BORE_GAS_VOL              2717 non-null   float64
#  10  BORE_WAT_VOL              2717 non-null   float64
# dtypes: datetime64[ns](1), float64(10)
# memory usage: 233.6 KB

# %%
df_5351.describe()
# Out:
#        ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  \
# count    2717.000000            2717.000000               2717.000000
# mean       23.050687             246.505180                101.647452
# std         3.438220              25.077625                  8.742068
# min         0.625000               0.000000                  0.000000
# 25%        24.000000             240.602292                 99.873083
# 50%        24.000000             247.191777                101.782098
# 75%        24.000000             261.519886                105.141984
# max        25.000000             289.897009                106.772733
#
#        AVG_CHOKE_SIZE_P    AVG_WHP_P    AVG_WHT_P  DP_CHOKE_SIZE  \
# count       2717.000000  2717.000000  2717.000000    2717.000000
# mean          72.917002    43.807395    85.825170      13.757965
# std           27.658527    18.125673     5.836733      16.542586
# min            2.485842     0.000000    12.134665       1.450701
# 25%           44.923847    31.499809    85.357485       2.616243
# 50%           76.692234    34.951201    87.383659       5.696694
# 75%          100.000000    49.828866    88.717042      17.151500
# max          100.000000   115.184383    93.509584      82.983969
#
#        BORE_OIL_VOL   BORE_GAS_VOL  BORE_WAT_VOL
# count   2717.000000    2717.000000   2717.000000
# mean    1443.872091  211714.204891   2620.978601
# std     1288.453491  181932.248688   1282.606590
# min        4.300000     856.020000    -59.190000
# 25%      330.840000   50906.870000   2126.160000
# 50%     1040.770000  164156.910000   3101.530000
# 75%     2235.480000  327273.000000   3492.760000
# max     5644.370000  789974.730000   5691.770000

# %%
## Some data points have ON_STREAM_HRS > 24...setting them to 24

for index in df_5351[df_5351.ON_STREAM_HRS > 24].index:
    df_5351.loc[index, "ON_STREAM_HRS"] = 24

# %%
## Since the Well head Pressure can't be zero for non-zero oil production, we are replacing it with the median value
df_5351.loc[df_5351[df_5351.AVG_WHP_P <= 1].index, "AVG_WHP_P"] = df_5351.AVG_WHP_P.median()

## Similarly, since the Downhole Pressure and Temperature can't be zero for non-zero oil production, 
## we are replacing it with the median value
df_5351.loc[df_5351[df_5351.AVG_DOWNHOLE_PRESSURE == 0].index, "AVG_DOWNHOLE_PRESSURE"] = df_5351.AVG_DOWNHOLE_PRESSURE.median()
df_5351.loc[df_5351[df_5351.AVG_DOWNHOLE_TEMPERATURE == 0].index, "AVG_DOWNHOLE_TEMPERATURE"] = df_5351.AVG_DOWNHOLE_TEMPERATURE.median()

# %%
df_5351.describe()
# Out:
#        ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  \
# count    2717.000000            2717.000000               2717.000000
# mean       23.049285             247.869875                102.209370
# std         3.437653              17.071416                  4.364058
# min         0.625000              49.450440                 20.959721
# 25%        24.000000             240.886223                 99.887850
# 50%        24.000000             247.191777                101.782098
# 75%        24.000000             261.519886                105.141984
# max        24.000000             289.897009                106.772733
#
#        AVG_CHOKE_SIZE_P    AVG_WHP_P    AVG_WHT_P  DP_CHOKE_SIZE  \
# count       2717.000000  2717.000000  2717.000000    2717.000000
# mean          72.917002    43.845806    85.825170      13.757965
# std           27.658527    18.069896     5.836733      16.542586
# min            2.485842    27.185420    12.134665       1.450701
# 25%           44.923847    31.508247    85.357485       2.616243
# 50%           76.692234    34.951201    87.383659       5.696694
# 75%          100.000000    49.828866    88.717042      17.151500
# max          100.000000   115.184383    93.509584      82.983969
#
#        BORE_OIL_VOL   BORE_GAS_VOL  BORE_WAT_VOL
# count   2717.000000    2717.000000   2717.000000
# mean    1443.872091  211714.204891   2620.978601
# std     1288.453491  181932.248688   1282.606590
# min        4.300000     856.020000    -59.190000
# 25%      330.840000   50906.870000   2126.160000
# 50%     1040.770000  164156.910000   3101.530000
# 75%     2235.480000  327273.000000   3492.760000
# max     5644.370000  789974.730000   5691.770000

# %%
## Sorting the values in ascending order wrt the date column

df_5351 = df_5351.sort_values(["DATEPRD"])
df_5351.reset_index(inplace = True, drop = True)

# %%
## Saving the cleaned 5351 well production data to excel file
working_df_path = dataset_path.parent / "working_df_v2.xlsx"
df_5351.to_excel(str(working_df_path), index = False)  ##index = False doesn't save the index

# %%
df = pd.read_excel(working_df_path)

# %% [markdown]
# We will use the average flow rate feature AVG_OIL_FLOW_RATE instead of BORE_OIL_VOL as the target variable as it is a more appropriate metric.

# %%
## Adding the feature for cummulative oil produced by shifting the cumulative sum of oil produced by 1 row downwards
## Not adding cummulative water and cummulative gas produced because they are highly correlated to Cummulative Oil Produced

# df["CUMM_OIL"] = np.r_[0, np.cumsum(df.loc[:,["BORE_OIL_VOL"]]).values.ravel()[1:]]

# %%
## Adding a field called AVG_OIL_FLOW_RATE

df["AVG_OIL_FLOW_RATE"] = df.BORE_OIL_VOL/df.ON_STREAM_HRS

# %%
df.head()
# Out:
#      DATEPRD  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  \
# 0 2008-07-13          24.00             260.866875                103.292880
# 1 2008-07-14           5.57             256.248230                104.017718
# 2 2008-07-15          24.00             254.982785                103.967009
# 3 2008-07-16          24.00             251.475921                104.210557
# 4 2008-07-17          24.00             249.346191                104.339184
#
#    AVG_CHOKE_SIZE_P   AVG_WHP_P  AVG_WHT_P  DP_CHOKE_SIZE  BORE_OIL_VOL  \
# 0         21.052993  100.714919  52.381899      69.539413       1735.26
# 1         27.223459   99.598318  71.115352      68.016167        592.36
# 2         27.277954   98.649941  67.590753      66.948884       2532.21
# 3         30.650552   95.658734  73.782251      63.663812       3030.71
# 4         32.562537   93.585252  78.035440      61.337700       3288.08
#
#    BORE_GAS_VOL  BORE_WAT_VOL  AVG_OIL_FLOW_RATE
# 0     252235.23          4.00          72.302500
# 1      88949.00          1.37         106.348294
# 2     373786.28          5.84         105.508750
# 3     447840.09          9.13         126.279583
# 4     474614.43          7.58         137.003333

# %%
## Defining a function to plot the Date vs Flow rate chart
def date_vs_prod(df, nf_plot = False):
    fig, ax_1 = plt.subplots()
    sns.scatterplot(data = df, x = "DATEPRD", y = "AVG_OIL_FLOW_RATE", hue = "AVG_OIL_FLOW_RATE", alpha = 0.5, size = 5, ax = ax_1,
                   legend = False, palette="crest")
    if nf_plot:
        nf_dates = df[df.ON_STREAM_HRS == 0]
        nf_dates = nf_dates.iloc[:,0].values
        for date in nf_dates:
            ax_1.axvline(date, color = "r" , linewidth = 1, alpha = 0.05)
    return fig

# %%
## Testing the above function
plot = date_vs_prod(df)

# %% [markdown]
# Now our data looks ready for EDA :)

# %% [markdown]
# ## EDA

# %%
# #Training dataset is taken to be all the data points before after April 2013 and before June 2015.
# # Validation and testing dataset is taken to be all the data points after June 2015

# df_5351_train = df_5351[(df_5351.DATEPRD >= pd.to_datetime("04/01/2013")) & (df_5351.DATEPRD < pd.to_datetime("06/01/2015"))]
# df_5351_val_test = df_5351[df_5351.DATEPRD >= pd.to_datetime("06/01/2015")]

# %%
## Visualizing the ditribution of the features in the dataset

cols = list(df.columns)
nrows = len(cols)/3 if len(cols)%3 == 0 else len(cols)//3+1
fig, ax = plt.subplots(nrows = int(nrows), ncols = 3, figsize = (15,15))
for index, (col, axis) in enumerate(zip(cols, ax.ravel())):
    sns.histplot(data=df, x = col, ax = axis)

# %%
df_corr = df.drop(columns = ["ON_STREAM_HRS", "BORE_GAS_VOL", "BORE_WAT_VOL", "BORE_OIL_VOL"], axis = 1)
corr_matrix = df_corr.corr()
fig = plt.figure(figsize = (8,4))
ax = sns.heatmap(corr_matrix, annot = True, cmap = "crest", linewidth = 0.5, 
            annot_kws = {"fontsize": 10}, fmt=".2f")
# Out:
# C:\Users\spect\AppData\Local\Temp\ipykernel_20984\2013007748.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df_corr.corr()

# %% [markdown]
# The above boxplot shows that Wellhead Pressure is highly positively correlated to Oil Production, which is to be expected.
#
# Also, Wellhead Pressure is highly positively correlated with Downhole Temperatue. WHy?
#
# Also, Wellhead Pressure is very highly positively correlated to DP Choke Size, which is also to be expected.
#
# Also, DP Choke Size is negatively correlated to AVG Choke SIZE P which is also expected.

# %% [markdown]
# ---

# %% [markdown]
# One interesting observation is that Well Head Temperature is not correlated with Downhole Temperature. Reasons for this are as follows:
#
# The wellhead temperature of an oil well will be somewhat less than the BHT. The amount of cooling as crude flows to the surface will depend on several factors:
#
# 1. The relative amounts of oil and water
# 2. The specific heats of oil and water
# 3. The flow rate, the gas/liquid ratio
# 4. The vertical-flow pressure drop that controls the gas liberated and the attendant cooling effect, and the thermal heat transfer rate from the wellbore.

# %%
## Visualizing the ditribution of the features in the dataset

cols = list(df.columns[1:])
nrows = len(cols)/3 if len(cols)%3 == 0 else len(cols)//3+1
fig, ax = plt.subplots(nrows = int(nrows), ncols = 3, figsize = (18,18))
for index, (col, axis) in enumerate(zip(cols, ax.ravel())):
    sns.boxplot(data=df, y = col, ax = axis)

# %% [markdown]
# ***

# %% [markdown]
# There is one clear outlier in AVG_OIL_FLOW_RATE...analysing that:

# %%
df[df.AVG_OIL_FLOW_RATE > 300]
# Out:
#         DATEPRD  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# 1365 2012-08-13          0.625             252.892348
#
#       AVG_DOWNHOLE_TEMPERATURE  AVG_CHOKE_SIZE_P  AVG_WHP_P  AVG_WHT_P  \
# 1365                 101.88657          7.777673  46.152546  83.714672
#
#       DP_CHOKE_SIZE  BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL  \
# 1365        17.2037        202.53       3754.12        -59.19
#
#       AVG_OIL_FLOW_RATE
# 1365            324.048

# %% [markdown]
# Since the above point is clearly an outlier, we will remove that point

# %%
df.drop(index = list(df[df.AVG_OIL_FLOW_RATE > 300].index), axis = 0, inplace = True)

# %% [markdown]
# ***

# %% [markdown]
# Why are there so many values with low downhole temperatures? Is the well head temperature also low at those points? Do these points occur during the winters?

# %%
## Analysing the abnormally low values of downhole temperature (values less than 90 deg)

df_temp = df[(df.AVG_DOWNHOLE_TEMPERATURE < 100) & (df.AVG_DOWNHOLE_PRESSURE < 220)]
df_temp
# Out:
#         DATEPRD  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# 243  2009-04-04       24.00000             142.195394
# 246  2009-04-09       15.58334             156.704604
# 252  2009-04-16       17.52500             126.438256
# 256  2009-04-20       24.00000             161.168309
# 276  2009-05-11       24.00000             131.509383
# 311  2009-06-15       13.60833             204.891693
# 521  2010-01-20       24.00000             194.357709
# 542  2010-02-10       24.00000             188.629729
# 555  2010-02-23       23.08333              71.154596
# 557  2010-02-25       18.50000              49.450440
# 1581 2013-05-15       24.00000              96.608705
# 1633 2013-07-08       24.00000             211.485592
# 1711 2013-09-27       16.83333             186.940785
# 1713 2013-09-29       24.00000             135.625829
# 1977 2014-06-26       16.50000             174.793144
# 1978 2014-06-27       23.50000             147.200708
# 2035 2014-08-28       23.50000             164.074053
# 2036 2014-08-29       24.00000             177.673720
#
#       AVG_DOWNHOLE_TEMPERATURE  AVG_CHOKE_SIZE_P  AVG_WHP_P  AVG_WHT_P  \
# 243                  62.097413         36.915852  82.265890  79.017304
# 246                  68.810278         32.956922  82.462544  71.992248
# 252                  57.945863         33.940204  76.983197  70.601237
# 256                  75.026294         38.396193  72.358102  78.249001
# 276                  62.529313         41.256309  67.970132  80.122545
# 311                  96.998262         33.790855  69.501117  72.837203
# 521                  87.218937         49.241114  52.011679  86.076854
# 542                  80.615963         41.727705  60.036823  89.643162
# 555                  30.076100         37.115075  63.935236  88.950753
# 557                  20.959721         40.528096  60.117145  87.488834
# 1581                 39.768824        100.000000  34.031163  85.874968
# 1633                 87.025056        100.000000  32.540497  89.268146
# 1711                 73.568923         52.943052  36.104318  85.850109
# 1713                 54.760490        100.000000  32.486093  87.065948
# 1977                 66.573972         51.030205  36.351034  81.300358
# 1978                 54.637708         74.268164  35.443482  87.022581
# 2035                 62.440891         76.428020  33.815602  85.062305
# 2036                 68.205620         99.290564  30.814119  86.924010
#
#       DP_CHOKE_SIZE  BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL  \
# 243       49.444290       4266.19     603057.78         39.67
# 246       50.463594       2094.72     291446.14          2.62
# 252       44.686935       2452.26     337254.14          1.42
# 256       39.642990       3990.32     539753.59          2.50
# 276       34.854465       4241.75     575312.38         18.76
# 311       37.502203       1724.89     248079.85         12.74
# 521       19.134864       2789.61     389180.91       2595.68
# 542       27.782542       2521.73     355402.62       2616.02
# 555       31.642675       2144.80     307980.27       2126.16
# 557       28.340810       1709.58     243034.51       1755.05
# 1581       4.874387        844.52     138409.00       3877.13
# 1633       3.785294        852.38     132899.95       3609.61
# 1711       7.354059        491.73      78722.08       2729.00
# 1713       2.992594        665.70      99793.64       3783.79
# 1977       8.167492        183.67      27523.85       1383.83
# 1978       5.757556        296.83      44840.61       2273.92
# 2035       5.779091        290.24      50596.19       2400.19
# 2036       2.017607        374.02      67084.42       3095.61
#
#       AVG_OIL_FLOW_RATE
# 243          177.757917
# 246          134.420477
# 252          139.929244
# 256          166.263333
# 276          176.739583
# 311          126.752511
# 521          116.233750
# 542          105.072083
# 555           92.915537
# 557           92.409730
# 1581          35.188333
# 1633          35.515833
# 1711          29.211689
# 1713          27.737500
# 1977          11.131515
# 1978          12.631064
# 2035          12.350638
# 2036          15.584167

# %% [markdown]
# From the above table, it is observed that the low values of downhole temperature coexists with low values of downhole pressure. This indicates erroneous values being produced by the downhole equipment measuring the downhole pressure and temperature. Therefore, we are going to replace these values with median values.

# %%
## Replacing the outliers in Downhole Pressure and Downhole Temperature with their medians

temp_median = df["AVG_DOWNHOLE_TEMPERATURE"].median()
press_median = df["AVG_DOWNHOLE_PRESSURE"].median()
df["AVG_DOWNHOLE_TEMPERATURE"] = df.AVG_DOWNHOLE_TEMPERATURE.apply(lambda temp: temp_median if temp < 100 else temp)
df["AVG_DOWNHOLE_PRESSURE"] = df.AVG_DOWNHOLE_PRESSURE.apply(lambda press: press_median if press < 220 else press)

# %% [markdown]
# ***

# %% [markdown]
# Doing seasonality analysis on the oil volume produced using FFT

# %%
freq = tf.signal.rfft(df.BORE_OIL_VOL)
plt.plot(np.abs(freq)[:10000])

# %% [markdown]
# The above graph shows that there is no seasonal trend in the oil production volume

# %% [markdown]
# ***

# %% [markdown]
# Analysing the correlation between wellhead pressure and oil flow rate

# %%
sns.scatterplot(x = df.AVG_WHP_P, y = df.AVG_OIL_FLOW_RATE, alpha = 0.5)
# Out:
# <AxesSubplot: xlabel='AVG_WHP_P', ylabel='AVG_OIL_FLOW_RATE'>

# %% [markdown]
# Analysing Wellhead Pressure vs Oil Flow Rate on yearwise basis for more in-depth analysis

# %%
df_temp = df.copy()
df_temp["Year"] = df_temp.DATEPRD.apply(lambda x: x.year)

# %%
years = np.unique(df_temp.Year)
years
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016], dtype=int64)

# %%
fig, ax = plt.subplots(nrows = 3, ncols= 3, figsize = (15,15))
for (year, axis) in zip(years, ax.ravel()):
    df_year = df_temp[df_temp.Year == year]
    sns.scatterplot(data = df_year, x = "AVG_WHP_P", y = "AVG_OIL_FLOW_RATE", alpha = 0.5, ax=axis, )
    axis.set(title = f"Year: {year}", xlim = [20, 110])

# %% [markdown]
# From the above plots, we can see that the high wellhead pressure datapoints (>80) mostly lie in the year 2008-09 plots, when the well was young, and producing high volumes of oil. As the time has progressed, the oil volume has also decreased alongwith the wellhead pressure.

# %%
# ## Implementing the above observations and removing the outliers in Wellhead Pressure values

# df["Year"] = df.DATEPRD.apply(lambda x: x.year)
# df = df[(df.Year <= 2009) | 
#         ((df.Year == 2010) & (df.AVG_WHP_P < 80)) |
#         ((df.Year > 2010) & (df.AVG_WHP_P < 60))]

# df.drop(columns = ["Year"], inplace = True, axis = 1) ## Dropping the Year column again as its no longer needed

# %% [markdown]
# ***

# %%
date_vs_prod(df)
plt.show()

# %% [markdown]
# # Modelling

# %% [markdown]
# ***

# %% [markdown]
# ### Preparing a function to apply all the pre-processing steps in a single go

# %%
def preprocessor(df_, train_start_date, val_date, test_date, DATEPROD = True, 
                 Day_col = False, Month_col = False, Year_col = False, scale = True):
    
    """
    Function for performing all the preprocessing steps in one go
    """
    
    # Creating a copy of the passed dataset so that the original dataset is not modified
    df = df_.copy()
    
    ## Removing Dates on which the well flowed for zero hours from the dataset
    df.drop(index = list(df[df.ON_STREAM_HRS == 0].index), axis = 0, inplace = True)
    df.reset_index(drop = True, inplace = True)
    
    ## Dropping the date points where the oil volume produced is equal to zero
    df.drop(index = list(df[df.BORE_OIL_VOL == 0].index), axis = 0, inplace = True)
    df.reset_index(drop = True, inplace = True)
    
    ## Some data points have ON_STREAM_HRS > 24...setting them to 24
    for index in df[df.ON_STREAM_HRS > 24].index:
        df.loc[index, "ON_STREAM_HRS"] = 24
    
    # Breaking the DATEPRD column into Day, Month and Year columns
    if Day_col:
        df["Day"] = df.DATEPRD.dt.day
    if Month_col:
        df["Month"] = df.DATEPRD.dt.month
    if Year_col:
        df["Year"] = df.DATEPRD.dt.year

    ## Removing features which are not needed
    features_x = ["ON_STREAM_HRS", 'BORE_GAS_VOL', 'BORE_WAT_VOL', "BORE_OIL_VOL"]
    df = df.drop(columns = features_x, axis = 1)
    
    ## Plotting graphs for visualizing the points taken into consideration while building the training, validation and 
    ## test datasets
    date_vs_prod(df)
    plt.axvline(pd.to_datetime(train_start_date), linestyle = "dotted", color = "orange")
    plt.axvline(pd.to_datetime(val_date), linestyle = "dotted", color = "orange")
    plt.axvline(pd.to_datetime(test_date), linestyle = "dotted", color = "orange")
    plt.title("ALL DATA POINTS")
    date_vs_prod(df[df.DATEPRD >= pd.to_datetime(train_start_date)])
    plt.axvline(pd.to_datetime(train_start_date), linestyle = "dotted", color = "orange")
    plt.axvline(pd.to_datetime(val_date), linestyle = "dotted", color = "orange")
    plt.axvline(pd.to_datetime(test_date), linestyle = "dotted", color = "orange")
    plt.title("DATA POINTS CONSIDERED")
    
    # Training dataset is taken to be all the data points after train_start_date and before val_date
    # Validation and testing dataset is taken to be all the data points after val_date
    df_train = df[(df.DATEPRD >= pd.to_datetime(train_start_date)) & (df.DATEPRD < pd.to_datetime(val_date))].copy()
    df_val_test = df[df.DATEPRD >= pd.to_datetime(val_date)].copy()
    
    ##_______ TO BE DONE AFTER SEPERATING TRAIN DATASET _________
    
#     ## Replacing the zero/na values in downhole pressure and temperature with the mean values
#     dhp_mean = df_train["AVG_DOWNHOLE_PRESSURE"].mean()
#     dht_mean = df_train["AVG_DOWNHOLE_TEMPERATURE"].mean()

#     for df_ in [df_train, df_val_test]:
#         dhp_index = df_[(df_.AVG_DOWNHOLE_PRESSURE.isna()) | (df_.AVG_DOWNHOLE_PRESSURE == 0)].index
#         dht_index = df_[(df_.AVG_DOWNHOLE_TEMPERATURE.isna()) | (df_.AVG_DOWNHOLE_PRESSURE == 0)].index

#         for index in dhp_index:
#             df_.loc[index, "AVG_DOWNHOLE_PRESSURE"] = dhp_mean

#         for index in dht_index:
#             df_.loc[index, "AVG_DOWNHOLE_TEMPERATURE"] = dht_mean
    
#     ## Removing outliers from the features in the training datset
#     df_train = df_train[
#         (df_train.AVG_DOWNHOLE_PRESSURE > 200) &
#         (df_train.AVG_DOWNHOLE_TEMPERATURE > 90) &
#         (df_train.AVG_WHP_P != 0) &
#         (df_train.AVG_WHP_P < 80) &
#         (df_train.AVG_WHT_P > 70) &
#         (df_train.DP_CHOKE_SIZE < 70)
#     ]
    
    # Creating X_train, y_train, X_val, y_val, X_test, y_test
    # Validation data is taken to be data points from val_date till test_date
    # Test data is taken to be data points from test_date till the last available date
    features_list = list(df_train.columns)
    features_list.remove("AVG_OIL_FLOW_RATE")

    y_train = df_train["AVG_OIL_FLOW_RATE"]
    X_train = df_train.loc[:,features_list]

    df_val = df_val_test[df_val_test.DATEPRD < pd.to_datetime(test_date)]
    df_test = df_val_test[df_val_test.DATEPRD >= pd.to_datetime(test_date)]

    y_val = df_val["AVG_OIL_FLOW_RATE"]
    X_val = df_val.loc[:,features_list]

    y_test = df_test["AVG_OIL_FLOW_RATE"]
    X_test = df_test.loc[:,features_list]
    
    # Dropping DATEPROD col
    if DATEPROD:
        for df_ in [X_train, X_val, X_test]:
            df_.drop(["DATEPRD"], axis = 1, inplace = True)
    features_ = list(X_train.columns)
    print(f" Features in the output datasets: {features_}")
    
    # Scaling the data using StandardScaler from sklearn
    if scale:
        from sklearn.preprocessing import StandardScaler
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
    
    # Printing the length of X_train, X_val and X_test datasets
    print(f"Total data points taken for training/validation/testing: {len(X_train) + len(X_val) + len(X_test)}")
    for X_name, X_df in zip(["Train", "Validation", "Test"], [X_train, X_val, X_test]):
        print(f"Data points in {X_name} are: {len(X_df)}")
    
    return (features_, X_train, y_train, X_val, y_val, X_test, y_test)

## Testing the above preprocessing function 

# (X_train, y_train, X_val, y_val, X_test, y_test) = preprocessor(df_5351, train_start_date="04/01/2013",
#                                                              val_date = "06/01/2015", test_date = "01/01/2016")

# %%
## Function for plotting predicted values vs actual values

def predict_plot(actual, predicted, fig_title = ""):
    """
    predict_plot(actual_values, predicted_values)
    """
    import matplotlib as mpl
    cmap = mpl.cm.get_cmap("cividis")
    fig, ax = plt.subplots(nrows = 1, ncols = 1)
    ax.scatter(actual, predicted, alpha = 0.2 , c = cmap((np.abs(actual)-np.abs(predicted))/np.abs(actual)))
    ax.set_xlabel("Actual values")
    ax.set_ylabel("Predicted values")
    ax.plot(np.linspace(actual.min(), actual.max(), 100), np.linspace(actual.min(), actual.max(), 100), "r--")
    ax.set_title(fig_title)
    sm = mpl.cm.ScalarMappable(cmap = cmap)
    cbar = plt.colorbar(sm)
    cbar.set_label('Error in predictions scaled to [0,1]', rotation=270)
    cbar.ax.set_yticklabels(['0','','','',"",'1'])
    plt.show()

# %% [markdown]
# ### Preparing the data and trying non-time series models (linear, SVM, ensembles, NN)

# %%
df.DATEPRD
# Out:
# 0      2008-07-13
# 1      2008-07-14
# 2      2008-07-15
# 3      2008-07-16
# 4      2008-07-17
#           ...
# 2712   2016-07-09
# 2713   2016-07-10
# 2714   2016-07-11
# 2715   2016-07-12
# 2716   2016-07-13
# Name: DATEPRD, Length: 2716, dtype: datetime64[ns]

# %%
(features, X_train, y_train, X_val, y_val, X_test, y_test) = preprocessor(df, train_start_date="01/01/2013",
                                                             val_date = "01/01/2015", test_date = "10/01/2015",
                                                               Day_col = False, Month_col = False, Year_col = False)
# Out:
#  Features in the output datasets: ['AVG_DOWNHOLE_PRESSURE', 'AVG_DOWNHOLE_TEMPERATURE', 'AVG_CHOKE_SIZE_P', 'AVG_WHP_P', 'AVG_WHT_P', 'DP_CHOKE_SIZE']
# Total data points taken for training/validation/testing: 1261
# Data points in Train are: 705
# Data points in Validation are: 269
# Data points in Test are: 287

# %% [markdown]
# ***

# %% [markdown]
# ## Implementing Decline Curve Analysis (DCA)

# %%
from scipy.optimize import curve_fit   #Importing the curve fit function from scipy package

def hyperbolic_equation(t, qi, b, di):
    """
    Hyperbolic decline curve equation
    Arguments:
        t: Float. Time since the well first came online, can be in various units 
        (days, months, etc) so long as they are consistent.
        qi: Float. Initial production rate when well first came online.
        b: Float. Hyperbolic decline constant
        di: Float. Nominal decline rate at time t=0
    Output: 
        Returns q, or the expected production rate at time t. Float.
    """
    return qi/((1.0+b*di*t)**(1.0/b))

def exponential_equation(t, qi, di):
    """
    Exponential decline curve equation
    Arguments:
        t: Float. Time since the well first came online, can be in various units 
        (days, months, etc) so long as they are consistent.
        qi: Float. Initial production rate when well first came online.
        di: Float. Nominal decline rate (constant)
    Output: 
        Returns q, or the expected production rate at time t. Float.
    """
    return qi*np.exp(-di*t)

def dca_plotter(flow_rates):
    """
    Plots DCA curves hyperbolica and exponential. Returns the constants of hyperbolic curve equation [qi_h, b, di_h]
    
    """

    def get_max_initial_production(flow_rates, number_days):
        return flow_rates[:number_days].max()
    
    def hyp_exp_plot(flow_rates, hyp_curve_fit, exp_curve_fit):
        """
        exp_curve_fit = [qi, di]
        hyp_curve_fit = [qi, b, di]
        """
        [qi_e, di_e] = exp_curve_fit
        [qi_h, b, di_h] = hyp_curve_fit
        
        fig = plt.figure(figsize = (10, 5))
        
        x = np.arange(len(flow_rates))
        fig = sns.scatterplot(x = x, y = flow_rates, label = "Flow Rate", color = "red", alpha = 0.8)
        fig = plt.plot(x, hyperbolic_equation(x, qi_h, b, di_h), label = f"Hyperbolic with b={b:.2E}",
                       color = "blue", linestyle = "dashed")
        fig = plt.plot(x, exponential_equation(x, qi_e, di_e), label = "Exponential", linestyle = "dashed", color = "k")
        plt.legend()
        return fig
    
    ## Getting the qi value
    qi = get_max_initial_production(flow_rates, 120)

    exp_values, exp_std = curve_fit(exponential_equation, np.arange(len(flow_rates)), flow_rates, bounds = (0, [qi, 100]))
    hyp_values, hyp_std = curve_fit(hyperbolic_equation, np.arange(len(flow_rates)), flow_rates, bounds = (0, [qi, 1, 100]))
    
    print(f"For exponential curve: qi = {exp_values[0]}, di = {exp_values[1]}")
    print(f"For hyperbolic curve: qi = {hyp_values[0]}, b = {hyp_values[1]}, di = {hyp_values[2]}")
    
    hyp_exp_plot(flow_rates, hyp_values, exp_values)
    
    return hyp_values

# %%
hyp_values = dca_plotter(y_train)
# Out:
# C:\Users\spect\AppData\Local\Temp\ipykernel_20984\3574825352.py:37: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   return flow_rates[:number_days].max()
# For exponential curve: qi = 42.920034519950654, di = 50.0
# For hyperbolic curve: qi = 43.46833332873359, b = 6.275600555918789e-09, di = 0.0016763162063637136

# %%
## Testing the hyperbolic equation obtained on training + validation data

from sklearn.metrics import mean_squared_error

Y = np.r_[y_train, y_val]
x = np.arange(len(Y))

[qi, b, di] = hyp_values

hyp = hyperbolic_equation(x, qi, b, di)
plt.scatter(x = x, y = Y, s = 5, color = "red")
plt.plot(x, hyp, linestyle = "dashed", color = "k")

## Calculating the MSE if we only use DCA for flowrate prediction

hyp_train_pred = hyp[:len(y_train)]
hyp_val_pred = hyp[len(y_train):]

hyp_train_mse = mean_squared_error(y_train, hyp_train_pred)
hyp_val_mse = mean_squared_error(y_val, hyp_val_pred)

print(f"MSE for DCA Hyperbolic curve on training data: {hyp_train_mse:.2f}")
print(f"MSE for DCA Hyperbolic curve on validation data: {hyp_val_mse:.2f}")
# Out:
# MSE for DCA Hyperbolic curve on training data: 17.03
# MSE for DCA Hyperbolic curve on validation data: 2.34

# %% [markdown]
# The Hyperbolic equation obtained from decline curve analysis fits the data points on the training and validation data very well
#
# Thus, the hyperbolic equation can be used to check the performance of our models

# %% [markdown]
# ***

# %% [markdown]
# ### Including the flow rates as predicted by DCA in the training, validation, and test data

# %% [markdown]
# The DCA will only be fitted on the training data for model selection and training+validation data for test data performance evaluation

# %% [markdown]
# Here, we will fit the DCA only on the training data and then use the hyperbolic equation obtained to get predicted flow rates

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

[qi, b, di] = hyp_values  ##hyp_values is obtained by fitting the curve using dca_plotter() function

X_ = np.r_[X_train, X_val, X_test]
hyp_q = hyperbolic_equation(np.arange(len(X_)), qi, b, di)
hyp_q_scaled = scaler.fit_transform(hyp_q.reshape(-1, 1))
X_ = np.c_[X_, hyp_q_scaled]

X_train_dca = X_[:len(X_train), :]
X_val_dca = X_[len(X_train):(len(X_val)+len(X_train)), :]
X_test_dca = X_[(len(X_train) + len(X_val)):, :]

## Modifying the features list to include the DCA column feature name
if features.count("DCA_FLOW_RATE") == 0:
    features = features + ["DCA_FLOW_RATE"]

# %%
X_train_dca.shape, X_val_dca.shape, X_test_dca.shape
# Out:
# ((705, 7), (269, 7), (287, 7))

# %%
features
# Out:
# ['AVG_DOWNHOLE_PRESSURE',
#  'AVG_DOWNHOLE_TEMPERATURE',
#  'AVG_CHOKE_SIZE_P',
#  'AVG_WHP_P',
#  'AVG_WHT_P',
#  'DP_CHOKE_SIZE',
#  'DCA_FLOW_RATE']

# %% [markdown]
# ***

# %% [markdown]
# Performing a final correlation analysis on the training and validation data

# %%
X_ = np.r_[X_train_dca, X_val_dca]
df_ = pd.DataFrame(X_, columns=features)
df_corr = df_.corr()
fig = plt.figure(figsize = (8,4))
ax = sns.heatmap(df_corr, annot = True, cmap = "crest", linewidth = 0.5, 
            annot_kws = {"fontsize": 10}, fmt=".2f")

# %% [markdown]
# ***

# %% [markdown]
# ### Creating a function to remove some specified features from a dataset

# %%
def feature_subsetter(features_list, features_sub, X_train, X_val, X_test):
    """
    `features_list` is a list containing the names of all the features. The order of the features in this list should 
        necessarily be the same to the order of the feautres in the dataset.
    `features_sub` is a list containing the names of the features to be kept. All other features will be removed.
    
    Return X_train, X_val, X_test
    """
    if len(features_list) != X_train.shape[1]:
        print(f"Error...no. of features in features list is {len(features_list)} and its not matching with the no. of columns in X_train {X_train.shape[1]}")
        
    features_sub_index = [features_list.index(f) for f in features_sub]

    ## Subsetting the original arrays
    X_train = X_train[:, features_sub_index]
    X_val = X_val[:, features_sub_index]
    X_test = X_test[:, features_sub_index]
    return X_train, X_val, X_test

# %%
features_sub = ["AVG_DOWNHOLE_TEMPERATURE", 'AVG_CHOKE_SIZE_P', 'AVG_WHP_P', 'AVG_WHT_P', 'DCA_FLOW_RATE']
X_train_dca, X_val_dca, X_test_dca = feature_subsetter(features,  features_sub, X_train_dca, X_val_dca, X_test_dca)

# %%
X_train_dca.shape, X_val_dca.shape, X_test_dca.shape
# Out:
# ((705, 5), (269, 5), (287, 5))

# %%
features = features_sub

# %% [markdown]
# ***

# %% [markdown]
# ## 1. Trying Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

rf = RandomForestRegressor(n_jobs=-1, random_state = 42)
rf.fit(X_train_dca, y_train)
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
mean_squared_error(rf.predict(X_val_dca), y_val)
# Out:
# 24.6127977665487

# %%
mean_squared_error(y_train, rf.predict(X_train_dca))
# Out:
# 0.6203848093483291

# %% [markdown]
# Such a significant difference in the mean squared error between training predictions and validation predictions signifies that the Random Forest model is overfitting

# %%
predict_plot(y_train, rf.predict(X_train_dca))
# Out:
# C:\Users\spect\AppData\Local\Temp\ipykernel_20984\1171456457.py:16: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)
# C:\Users\spect\AppData\Local\Temp\ipykernel_20984\1171456457.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cbar.ax.set_yticklabels(['0','','','',"",'1'])

# %%
predict_plot(y_val, rf.predict(X_val_dca))
# Out:
# C:\Users\spect\AppData\Local\Temp\ipykernel_20984\1171456457.py:16: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)
# C:\Users\spect\AppData\Local\Temp\ipykernel_20984\1171456457.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cbar.ax.set_yticklabels(['0','','','',"",'1'])

# %%
fig, ax = plt.subplots(figsize = (15,5))
sns.histplot(y_train, label = "Training Set")
sns.histplot(y_val, label = "Validation Set")
plt.legend()

# %% [markdown]
# Feature importance in the Random Forest Model

# %%
rf_fi = rf.feature_importances_
df_fi = pd.DataFrame(data = rf_fi, index = features, columns=["RF_FEATURE_IMPORTANCE"])
df_fi.plot.bar()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ***

# %% [markdown]
# ## 2. Trying SVM

# %% [markdown]
# ### 2.1 SVM RBF Kernel

# %%
from sklearn.svm import SVR
svr = SVR(C = 100, epsilon = 6)
svr.fit(X_train_dca, y_train)
# Out:
# SVR(C=100, epsilon=6)

# %%
mean_squared_error(y_val, svr.predict(X_val_dca))
# Out:
# 35.63799003843523

# %%
mean_squared_error(y_train, svr.predict(X_train_dca))
# Out:
# 8.899121157283222

# %%
predict_plot(y_train, svr.predict(X_train_dca))
# Out:
# C:\Users\spect\AppData\Local\Temp\ipykernel_20984\1171456457.py:16: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)
# C:\Users\spect\AppData\Local\Temp\ipykernel_20984\1171456457.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cbar.ax.set_yticklabels(['0','','','',"",'1'])

# %%
predict_plot(y_val, svr.predict(X_val_dca))
# Out:
# C:\Users\spect\AppData\Local\Temp\ipykernel_20984\1171456457.py:16: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)
# C:\Users\spect\AppData\Local\Temp\ipykernel_20984\1171456457.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cbar.ax.set_yticklabels(['0','','','',"",'1'])

# %% [markdown]
# ### 2.2 SVM Poly kernel

# %% [markdown]
# Degree = 3

# %%
from sklearn.svm import SVR
svm_poly_3 = SVR(kernel = "poly", degree = 4, epsilon = 0.1)
svm_poly_3.fit(X_train_dca, y_train)
# Out:
# SVR(degree=4, kernel='poly')

# %%
mean_squared_error(y_val, svm_poly_3.predict(X_val_dca))
# Out:
# 174.97341804336878

# %%
mean_squared_error(y_train, svm_poly_3.predict(X_train_dca))
# Out:
# 27.872128295127098

# %%
predict_plot(y_train, svm_poly_3.predict(X_train_dca))
# Out:
# C:\Users\spect\AppData\Local\Temp\ipykernel_20984\1171456457.py:16: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)
# C:\Users\spect\AppData\Local\Temp\ipykernel_20984\1171456457.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cbar.ax.set_yticklabels(['0','','','',"",'1'])

# %% [markdown]
# ## 3. Neural Networks

# %%
## Trying MLP lyers from scikit-learn

from sklearn.neural_network import MLPRegressor
mlp_reg = MLPRegressor([100,10,1], max_iter = 10000, verbose = 2)
mlp_reg.fit(X_train_dca, y_train)
# Out:
# Iteration 1, loss = 367.32227236
# Iteration 2, loss = 366.30407842
# Iteration 3, loss = 365.42157855
# Iteration 4, loss = 364.70390782
# Iteration 5, loss = 364.08534812
# Iteration 6, loss = 362.91211978
# Iteration 7, loss = 360.71920726
# Iteration 8, loss = 357.64984844
# Iteration 9, loss = 353.79403765
# Iteration 10, loss = 349.49081996
# Iteration 11, loss = 345.15254974
# Iteration 12, loss = 340.70563739
# Iteration 13, loss = 335.71090862
# Iteration 14, loss = 330.32588251
# Iteration 15, loss = 324.44801206
# Iteration 16, loss = 318.10346661
# Iteration 17, loss = 311.39692624
# Iteration 18, loss = 304.12734133
# Iteration 19, loss = 296.40681338
# Iteration 20, loss = 288.18167939
# Iteration 21, loss = 279.36233952
# Iteration 22, loss = 270.07805107
# Iteration 23, loss = 260.01356008
# Iteration 24, loss = 249.42113273
# Iteration 25, loss = 238.34693513
# Iteration 26, loss = 226.76027944
# Iteration 27, loss = 214.27101745
# Iteration 28, loss = 201.55663834
# Iteration 29, loss = 188.33014224
# Iteration 30, loss = 174.77765331
# Iteration 31, loss = 161.02000794
# Iteration 32, loss = 147.31883785
# Iteration 33, loss = 133.27675585
# Iteration 34, loss = 119.86404934
# Iteration 35, loss = 106.53890641
# Iteration 36, loss = 93.81114637
# Iteration 37, loss = 81.62717997
# Iteration 38, loss = 70.77941406
# Iteration 39, loss = 60.51863071
# Iteration 40, loss = 51.48390613
# Iteration 41, loss = 43.88486724
# Iteration 42, loss = 37.29585482
# Iteration 43, loss = 31.94853694
# Iteration 44, loss = 27.67218403
# Iteration 45, loss = 24.47274264
# Iteration 46, loss = 21.95084315
# Iteration 47, loss = 19.98499196
# Iteration 48, loss = 18.54607937
# Iteration 49, loss = 17.33616003
# Iteration 50, loss = 16.30483744
# Iteration 51, loss = 15.41375679
# Iteration 52, loss = 14.58777322
# Iteration 53, loss = 13.88982867
# Iteration 54, loss = 13.20922401
# Iteration 55, loss = 12.58623049
# Iteration 56, loss = 12.02075883
# Iteration 57, loss = 11.49229180
# Iteration 58, loss = 11.00453111
# Iteration 59, loss = 10.54861617
# Iteration 60, loss = 10.15906423
# Iteration 61, loss = 9.75107726
# Iteration 62, loss = 9.42754078
# Iteration 63, loss = 9.10804835
# Iteration 64, loss = 8.80892767
# Iteration 65, loss = 8.52584124
# Iteration 66, loss = 8.27598285
# Iteration 67, loss = 8.04164399
# Iteration 68, loss = 7.84024717
# Iteration 69, loss = 7.61633038
# Iteration 70, loss = 7.42483137
# Iteration 71, loss = 7.24012287
# Iteration 72, loss = 7.05732608
# Iteration 73, loss = 6.90032483
# Iteration 74, loss = 6.74143239
# Iteration 75, loss = 6.59679533
# Iteration 76, loss = 6.46586099
# Iteration 77, loss = 6.33956496
# Iteration 78, loss = 6.22721496
# Iteration 79, loss = 6.11255126
# Iteration 80, loss = 6.00281128
# Iteration 81, loss = 5.89833239
# Iteration 82, loss = 5.81958824
# Iteration 83, loss = 5.72721105
# Iteration 84, loss = 5.66288071
# Iteration 85, loss = 5.57437814
# Iteration 86, loss = 5.49780418
# Iteration 87, loss = 5.42675569
# Iteration 88, loss = 5.36067340
# Iteration 89, loss = 5.30415073
# Iteration 90, loss = 5.24814785
# Iteration 91, loss = 5.19114686
# Iteration 92, loss = 5.13294397
# Iteration 93, loss = 5.07839606
# Iteration 94, loss = 5.04467524
# Iteration 95, loss = 4.98705550
# Iteration 96, loss = 4.94214903
# Iteration 97, loss = 4.90045721
# Iteration 98, loss = 4.85264021
# Iteration 99, loss = 4.81620051
# Iteration 100, loss = 4.77188922
# Iteration 101, loss = 4.73665082
# Iteration 102, loss = 4.70051178
# Iteration 103, loss = 4.67171115
# Iteration 104, loss = 4.62862451
# Iteration 105, loss = 4.59723967
# Iteration 106, loss = 4.56513663
# Iteration 107, loss = 4.53831803
# Iteration 108, loss = 4.50759890
# Iteration 109, loss = 4.47939509
# Iteration 110, loss = 4.44673322
# Iteration 111, loss = 4.41601922
# Iteration 112, loss = 4.38884061
# Iteration 113, loss = 4.37197286
# Iteration 114, loss = 4.34231345
# Iteration 115, loss = 4.32361158
# Iteration 116, loss = 4.29437681
# Iteration 117, loss = 4.26888893
# Iteration 118, loss = 4.25200912
# Iteration 119, loss = 4.22943030
# Iteration 120, loss = 4.20416724
# Iteration 121, loss = 4.18019406
# Iteration 122, loss = 4.16132175
# Iteration 123, loss = 4.14147938
# Iteration 124, loss = 4.12085052
# Iteration 125, loss = 4.10192958
# Iteration 126, loss = 4.08300555
# Iteration 127, loss = 4.06050491
# Iteration 128, loss = 4.04178166
# Iteration 129, loss = 4.01821426
# Iteration 130, loss = 4.00930710
# Iteration 131, loss = 3.99614738
# Iteration 132, loss = 3.97966698
# Iteration 133, loss = 3.94936554
# Iteration 134, loss = 3.93250824
# Iteration 135, loss = 3.91409396
# Iteration 136, loss = 3.90196956
# Iteration 137, loss = 3.88223238
# Iteration 138, loss = 3.87125472
# Iteration 139, loss = 3.84991495
# Iteration 140, loss = 3.83396071
# Iteration 141, loss = 3.82493835
# Iteration 142, loss = 3.80810844
# Iteration 143, loss = 3.80732630
# Iteration 144, loss = 3.77536272
# Iteration 145, loss = 3.75900940
# Iteration 146, loss = 3.74593322
# Iteration 147, loss = 3.73062441
# Iteration 148, loss = 3.71818398
# Iteration 149, loss = 3.70527695
# Iteration 150, loss = 3.69182538
# Iteration 151, loss = 3.68138763
# Iteration 152, loss = 3.66368941
# Iteration 153, loss = 3.65220539
# Iteration 154, loss = 3.63730988
# Iteration 155, loss = 3.62706360
# Iteration 156, loss = 3.60959647
# Iteration 157, loss = 3.60748821
# Iteration 158, loss = 3.58993984
# Iteration 159, loss = 3.57356761
# Iteration 160, loss = 3.56057964
# Iteration 161, loss = 3.54637769
# Iteration 162, loss = 3.53395669
# Iteration 163, loss = 3.52347086
# Iteration 164, loss = 3.50711798
# Iteration 165, loss = 3.50262742
# Iteration 166, loss = 3.48841486
# Iteration 167, loss = 3.47366874
# Iteration 168, loss = 3.46412150
# Iteration 169, loss = 3.45336010
# Iteration 170, loss = 3.43707959
# Iteration 171, loss = 3.43061334
# Iteration 172, loss = 3.41384730
# Iteration 173, loss = 3.40405234
# Iteration 174, loss = 3.39742509
# Iteration 175, loss = 3.38285477
# Iteration 176, loss = 3.37446687
# Iteration 177, loss = 3.35992118
# Iteration 178, loss = 3.34940766
# Iteration 179, loss = 3.33924709
# Iteration 180, loss = 3.33047557
# Iteration 181, loss = 3.31750429
# Iteration 182, loss = 3.30892644
# Iteration 183, loss = 3.30241063
# Iteration 184, loss = 3.29560960
# Iteration 185, loss = 3.27826432
# Iteration 186, loss = 3.27355616
# Iteration 187, loss = 3.25910900
# Iteration 188, loss = 3.25937408
# Iteration 189, loss = 3.24466719
# Iteration 190, loss = 3.23214473
# Iteration 191, loss = 3.22526434
# Iteration 192, loss = 3.20914224
# Iteration 193, loss = 3.21010538
# Iteration 194, loss = 3.20272451
# Iteration 195, loss = 3.20090530
# Iteration 196, loss = 3.17832320
# Iteration 197, loss = 3.16943657
# Iteration 198, loss = 3.16560415
# Iteration 199, loss = 3.16234091
# Iteration 200, loss = 3.14840131
# Iteration 201, loss = 3.14108608
# Iteration 202, loss = 3.13486802
# Iteration 203, loss = 3.12653420
# Iteration 204, loss = 3.11994713
# Iteration 205, loss = 3.11763999
# Iteration 206, loss = 3.10789205
# Iteration 207, loss = 3.09632494
# Iteration 208, loss = 3.08849381
# Iteration 209, loss = 3.07581740
# Iteration 210, loss = 3.07414923
# Iteration 211, loss = 3.06590318
# Iteration 212, loss = 3.05921711
# Iteration 213, loss = 3.04973153
# Iteration 214, loss = 3.04483933
# Iteration 215, loss = 3.04047718
# Iteration 216, loss = 3.03892773
# Iteration 217, loss = 3.02764185
# Iteration 218, loss = 3.02090695
# Iteration 219, loss = 3.02519476
# Iteration 220, loss = 3.01006449
# Iteration 221, loss = 3.00156911
# Iteration 222, loss = 2.99462251
# Iteration 223, loss = 2.98924903
# Iteration 224, loss = 2.98132845
# Iteration 225, loss = 2.97638412
# Iteration 226, loss = 2.97341104
# Iteration 227, loss = 2.96330572
# Iteration 228, loss = 2.95985408
# Iteration 229, loss = 2.95285157
# Iteration 230, loss = 2.94963685
# Iteration 231, loss = 2.94808897
# Iteration 232, loss = 2.94339105
# Iteration 233, loss = 2.93879636
# Iteration 234, loss = 2.93393064
# Iteration 235, loss = 2.91990088
# Iteration 236, loss = 2.91960841
# Iteration 237, loss = 2.91704793
# Iteration 238, loss = 2.91170675
# Iteration 239, loss = 2.90278004
# Iteration 240, loss = 2.89514979
# Iteration 241, loss = 2.89134580
# Iteration 242, loss = 2.88721758
# Iteration 243, loss = 2.88357528
# Iteration 244, loss = 2.87813457
# Iteration 245, loss = 2.87384886
# Iteration 246, loss = 2.86641398
# Iteration 247, loss = 2.87166654
# Iteration 248, loss = 2.86391052
# Iteration 249, loss = 2.85876255
# Iteration 250, loss = 2.85316015
# Iteration 251, loss = 2.85192107
# Iteration 252, loss = 2.84287517
# Iteration 253, loss = 2.83856443
# Iteration 254, loss = 2.83449689
# Iteration 255, loss = 2.83422517
# Iteration 256, loss = 2.83322765
# Iteration 257, loss = 2.82165905
# Iteration 258, loss = 2.82375207
# Iteration 259, loss = 2.82471712
# Iteration 260, loss = 2.81922073
# Iteration 261, loss = 2.80922739
# Iteration 262, loss = 2.80489290
# Iteration 263, loss = 2.80106701
# Iteration 264, loss = 2.79728881
# Iteration 265, loss = 2.79741743
# Iteration 266, loss = 2.78926924
# Iteration 267, loss = 2.79429219
# Iteration 268, loss = 2.78442314
# Iteration 269, loss = 2.78079165
# Iteration 270, loss = 2.77944146
# Iteration 271, loss = 2.77525218
# Iteration 272, loss = 2.77178928
# Iteration 273, loss = 2.76370281
# Iteration 274, loss = 2.76616420
# Iteration 275, loss = 2.76782563
# Iteration 276, loss = 2.75980967
# Iteration 277, loss = 2.75063287
# Iteration 278, loss = 2.74794735
# Iteration 279, loss = 2.74458416
# Iteration 280, loss = 2.74294330
# Iteration 281, loss = 2.74139379
# Iteration 282, loss = 2.73730119
# Iteration 283, loss = 2.73409265
# Iteration 284, loss = 2.73156553
# Iteration 285, loss = 2.72831314
# Iteration 286, loss = 2.72422572
# Iteration 287, loss = 2.73120223
# Iteration 288, loss = 2.71529869
# Iteration 289, loss = 2.71492624
# Iteration 290, loss = 2.71098505
# Iteration 291, loss = 2.70784287
# Iteration 292, loss = 2.70909208
# Iteration 293, loss = 2.70189633
# Iteration 294, loss = 2.69964620
# Iteration 295, loss = 2.70326674
# Iteration 296, loss = 2.69310147
# Iteration 297, loss = 2.68472849
# Iteration 298, loss = 2.68401007
# Iteration 299, loss = 2.69851805
# Iteration 300, loss = 2.68536561
# Iteration 301, loss = 2.67535575
# Iteration 302, loss = 2.67361990
# Iteration 303, loss = 2.67426083
# Iteration 304, loss = 2.66450468
# Iteration 305, loss = 2.65940516
# Iteration 306, loss = 2.65982186
# Iteration 307, loss = 2.65677112
# Iteration 308, loss = 2.64949839
# Iteration 309, loss = 2.65037394
# Iteration 310, loss = 2.64292739
# Iteration 311, loss = 2.64189745
# Iteration 312, loss = 2.64020727
# Iteration 313, loss = 2.63452164
# Iteration 314, loss = 2.63292505
# Iteration 315, loss = 2.63132586
# Iteration 316, loss = 2.62801822
# Iteration 317, loss = 2.62227518
# Iteration 318, loss = 2.61865310
# Iteration 319, loss = 2.61730027
# Iteration 320, loss = 2.61617148
# Iteration 321, loss = 2.61331096
# Iteration 322, loss = 2.61085510
# Iteration 323, loss = 2.61267845
# Iteration 324, loss = 2.61919784
# Iteration 325, loss = 2.60441713
# Iteration 326, loss = 2.59645710
# Iteration 327, loss = 2.59504925
# Iteration 328, loss = 2.59549038
# Iteration 329, loss = 2.59034613
# Iteration 330, loss = 2.58695518
# Iteration 331, loss = 2.58194493
# Iteration 332, loss = 2.58456058
# Iteration 333, loss = 2.58270668
# Iteration 334, loss = 2.57389019
# Iteration 335, loss = 2.57631276
# Iteration 336, loss = 2.56758227
# Iteration 337, loss = 2.56655229
# Iteration 338, loss = 2.56732070
# Iteration 339, loss = 2.56730598
# Iteration 340, loss = 2.55640992
# Iteration 341, loss = 2.55472433
# Iteration 342, loss = 2.55000031
# Iteration 343, loss = 2.54854892
# Iteration 344, loss = 2.54575167
# Iteration 345, loss = 2.54189990
# Iteration 346, loss = 2.55218472
# Iteration 347, loss = 2.55253079
# Iteration 348, loss = 2.53612569
# Iteration 349, loss = 2.53895807
# Iteration 350, loss = 2.53029145
# Iteration 351, loss = 2.52491780
# Iteration 352, loss = 2.54197482
# Iteration 353, loss = 2.52813552
# Iteration 354, loss = 2.51561451
# Iteration 355, loss = 2.51843669
# Iteration 356, loss = 2.52432683
# Iteration 357, loss = 2.51433053
# Iteration 358, loss = 2.50991514
# Iteration 359, loss = 2.50386326
# Iteration 360, loss = 2.50098665
# Iteration 361, loss = 2.50112316
# Iteration 362, loss = 2.49549189
# Iteration 363, loss = 2.49094669
# Iteration 364, loss = 2.48854273
# Iteration 365, loss = 2.49066792
# Iteration 366, loss = 2.48699300
# Iteration 367, loss = 2.47924693
# Iteration 368, loss = 2.47569539
# Iteration 369, loss = 2.47213275
# Iteration 370, loss = 2.47248537
# Iteration 371, loss = 2.46885835
# Iteration 372, loss = 2.46807857
# Iteration 373, loss = 2.46258896
# Iteration 374, loss = 2.46126127
# Iteration 375, loss = 2.45654970
# Iteration 376, loss = 2.45454011
# Iteration 377, loss = 2.45612272
# Iteration 378, loss = 2.44599079
# Iteration 379, loss = 2.45572391
# Iteration 380, loss = 2.45232070
# Iteration 381, loss = 2.43937488
# Iteration 382, loss = 2.44876185
# Iteration 383, loss = 2.44206366
# Iteration 384, loss = 2.45951452
# Iteration 385, loss = 2.44075548
# Iteration 386, loss = 2.44882623
# Iteration 387, loss = 2.43159212
# Iteration 388, loss = 2.41855512
# Iteration 389, loss = 2.43826832
# Iteration 390, loss = 2.44528509
# Iteration 391, loss = 2.42761514
# Iteration 392, loss = 2.41447759
# Iteration 393, loss = 2.43848922
# Iteration 394, loss = 2.42120098
# Iteration 395, loss = 2.40970849
# Iteration 396, loss = 2.40901558
# Iteration 397, loss = 2.40720104
# Iteration 398, loss = 2.40193405
# Iteration 399, loss = 2.39957609
# Iteration 400, loss = 2.39889396
# Iteration 401, loss = 2.39530005
# Iteration 402, loss = 2.40108829
# Iteration 403, loss = 2.39080254
# Iteration 404, loss = 2.39209369
# Iteration 405, loss = 2.39074611
# Iteration 406, loss = 2.38982436
# Iteration 407, loss = 2.38662422
# Iteration 408, loss = 2.38383885
# Iteration 409, loss = 2.37624059
# Iteration 410, loss = 2.39806254
# Iteration 411, loss = 2.38928935
# Iteration 412, loss = 2.36951364
# Iteration 413, loss = 2.37219503
# Iteration 414, loss = 2.37282844
# Iteration 415, loss = 2.37698699
# Iteration 416, loss = 2.36097896
# Iteration 417, loss = 2.37726348
# Iteration 418, loss = 2.35706962
# Iteration 419, loss = 2.35346145
# Iteration 420, loss = 2.36056223
# Iteration 421, loss = 2.35709509
# Iteration 422, loss = 2.34759510
# Iteration 423, loss = 2.34723711
# Iteration 424, loss = 2.35007373
# Iteration 425, loss = 2.34105386
# Iteration 426, loss = 2.33737356
# Iteration 427, loss = 2.33639514
# Iteration 428, loss = 2.33479152
# Iteration 429, loss = 2.33864111
# Iteration 430, loss = 2.33003521
# Iteration 431, loss = 2.33001186
# Iteration 432, loss = 2.32966870
# Iteration 433, loss = 2.32744215
# Iteration 434, loss = 2.31759760
# Iteration 435, loss = 2.32153880
# Iteration 436, loss = 2.33054601
# Iteration 437, loss = 2.32790474
# Iteration 438, loss = 2.31917107
# Iteration 439, loss = 2.31712297
# Iteration 440, loss = 2.31364944
# Iteration 441, loss = 2.30683142
# Iteration 442, loss = 2.30346560
# Iteration 443, loss = 2.30742323
# Iteration 444, loss = 2.30623290
# Iteration 445, loss = 2.29759898
# Iteration 446, loss = 2.30164337
# Iteration 447, loss = 2.30293273
# Iteration 448, loss = 2.30508986
# Iteration 449, loss = 2.29583354
# Iteration 450, loss = 2.29327787
# Iteration 451, loss = 2.29554588
# Iteration 452, loss = 2.28659863
# Iteration 453, loss = 2.28999147
# Iteration 454, loss = 2.28576173
# Iteration 455, loss = 2.28325696
# Iteration 456, loss = 2.27756789
# Iteration 457, loss = 2.27643953
# Iteration 458, loss = 2.27317704
# Iteration 459, loss = 2.27441972
# Iteration 460, loss = 2.27057382
# Iteration 461, loss = 2.26025998
# Iteration 462, loss = 2.26834183
# Iteration 463, loss = 2.27296311
# Iteration 464, loss = 2.28432609
# Iteration 465, loss = 2.26446951
# Iteration 466, loss = 2.25813363
# Iteration 467, loss = 2.25652588
# Iteration 468, loss = 2.25068607
# Iteration 469, loss = 2.25474576
# Iteration 470, loss = 2.24833416
# Iteration 471, loss = 2.24294266
# Iteration 472, loss = 2.24414376
# Iteration 473, loss = 2.24077321
# Iteration 474, loss = 2.23957689
# Iteration 475, loss = 2.23854195
# Iteration 476, loss = 2.23140213
# Iteration 477, loss = 2.23581102
# Iteration 478, loss = 2.23685410
# Iteration 479, loss = 2.22809102
# Iteration 480, loss = 2.22488745
# Iteration 481, loss = 2.22405411
# Iteration 482, loss = 2.22737823
# Iteration 483, loss = 2.22659548
# Iteration 484, loss = 2.22568465
# Iteration 485, loss = 2.21431766
# Iteration 486, loss = 2.21380727
# Iteration 487, loss = 2.21252263
# Iteration 488, loss = 2.21457737
# Iteration 489, loss = 2.21098104
# Iteration 490, loss = 2.20858728
# Iteration 491, loss = 2.21361557
# Iteration 492, loss = 2.20428229
# Iteration 493, loss = 2.20834422
# Iteration 494, loss = 2.20230308
# Iteration 495, loss = 2.20110955
# Iteration 496, loss = 2.19602529
# Iteration 497, loss = 2.20029918
# Iteration 498, loss = 2.19218761
# Iteration 499, loss = 2.19386973
# Iteration 500, loss = 2.20268752
# Iteration 501, loss = 2.19589348
# Iteration 502, loss = 2.18345301
# Iteration 503, loss = 2.18429364
# Iteration 504, loss = 2.18049957
# Iteration 505, loss = 2.18044009
# Iteration 506, loss = 2.17819756
# Iteration 507, loss = 2.17378725
# Iteration 508, loss = 2.17835713
# Iteration 509, loss = 2.17228049
# Iteration 510, loss = 2.17450200
# Iteration 511, loss = 2.17051731
# Iteration 512, loss = 2.17345840
# Iteration 513, loss = 2.17162723
# Iteration 514, loss = 2.16747385
# Iteration 515, loss = 2.16950730
# Iteration 516, loss = 2.15651875
# Iteration 517, loss = 2.16367803
# Iteration 518, loss = 2.15750753
# Iteration 519, loss = 2.15782825
# Iteration 520, loss = 2.15312139
# Iteration 521, loss = 2.14943053
# Iteration 522, loss = 2.14870915
# Iteration 523, loss = 2.14382132
# Iteration 524, loss = 2.14409577
# Iteration 525, loss = 2.14362093
# Iteration 526, loss = 2.13913604
# Iteration 527, loss = 2.14099292
# Iteration 528, loss = 2.13364151
# Iteration 529, loss = 2.13662205
# Iteration 530, loss = 2.13394842
# Iteration 531, loss = 2.12971893
# Iteration 532, loss = 2.13332088
# Iteration 533, loss = 2.13913738
# Iteration 534, loss = 2.12314246
# Iteration 535, loss = 2.14160771
# Iteration 536, loss = 2.13002899
# Iteration 537, loss = 2.11406531
# Iteration 538, loss = 2.11844130
# Iteration 539, loss = 2.11801438
# Iteration 540, loss = 2.11227488
# Iteration 541, loss = 2.11387657
# Iteration 542, loss = 2.10699890
# Iteration 543, loss = 2.11563224
# Iteration 544, loss = 2.10821909
# Iteration 545, loss = 2.10503585
# Iteration 546, loss = 2.10246129
# Iteration 547, loss = 2.11599538
# Iteration 548, loss = 2.10063785
# Iteration 549, loss = 2.09532580
# Iteration 550, loss = 2.09299511
# Iteration 551, loss = 2.09768842
# Iteration 552, loss = 2.09162140
# Iteration 553, loss = 2.08613022
# Iteration 554, loss = 2.08457491
# Iteration 555, loss = 2.08437644
# Iteration 556, loss = 2.08581076
# Iteration 557, loss = 2.08309696
# Iteration 558, loss = 2.08065345
# Iteration 559, loss = 2.07878817
# Iteration 560, loss = 2.07729482
# Iteration 561, loss = 2.07385749
# Iteration 562, loss = 2.07131532
# Iteration 563, loss = 2.06419944
# Iteration 564, loss = 2.06629655
# Iteration 565, loss = 2.06711304
# Iteration 566, loss = 2.06348017
# Iteration 567, loss = 2.05999601
# Iteration 568, loss = 2.06461357
# Iteration 569, loss = 2.05828048
# Iteration 570, loss = 2.05556459
# Iteration 571, loss = 2.04888930
# Iteration 572, loss = 2.05904824
# Iteration 573, loss = 2.04999032
# Iteration 574, loss = 2.05340676
# Iteration 575, loss = 2.04984400
# Iteration 576, loss = 2.04578788
# Iteration 577, loss = 2.04066917
# Iteration 578, loss = 2.03904471
# Iteration 579, loss = 2.03886892
# Iteration 580, loss = 2.03603802
# Iteration 581, loss = 2.03751199
# Iteration 582, loss = 2.03906444
# Iteration 583, loss = 2.03078602
# Iteration 584, loss = 2.02921731
# Iteration 585, loss = 2.02766634
# Iteration 586, loss = 2.02196027
# Iteration 587, loss = 2.02564938
# Iteration 588, loss = 2.02478048
# Iteration 589, loss = 2.01944539
# Iteration 590, loss = 2.01965982
# Iteration 591, loss = 2.01315185
# Iteration 592, loss = 2.01318808
# Iteration 593, loss = 2.01306381
# Iteration 594, loss = 2.01432460
# Iteration 595, loss = 2.00999877
# Iteration 596, loss = 2.00687341
# Iteration 597, loss = 2.00465403
# Iteration 598, loss = 2.01615310
# Iteration 599, loss = 1.99987139
# Iteration 600, loss = 1.99711499
# Iteration 601, loss = 2.00312826
# Iteration 602, loss = 1.99959975
# Iteration 603, loss = 1.99392560
# Iteration 604, loss = 1.99759014
# Iteration 605, loss = 1.99382889
# Iteration 606, loss = 1.99536341
# Iteration 607, loss = 1.99353483
# Iteration 608, loss = 1.98695109
# Iteration 609, loss = 1.99756381
# Iteration 610, loss = 1.97915404
# Iteration 611, loss = 1.97703329
# Iteration 612, loss = 1.99492831
# Iteration 613, loss = 1.99179157
# Iteration 614, loss = 1.98059902
# Iteration 615, loss = 1.97765694
# Iteration 616, loss = 1.97518380
# Iteration 617, loss = 1.97368438
# Iteration 618, loss = 1.97879518
# Iteration 619, loss = 1.97668347
# Iteration 620, loss = 1.96937000
# Iteration 621, loss = 1.96788446
# Iteration 622, loss = 1.97756236
# Iteration 623, loss = 1.96491638
# Iteration 624, loss = 1.96178891
# Iteration 625, loss = 1.96353725
# Iteration 626, loss = 1.96466596
# Iteration 627, loss = 1.95486009
# Iteration 628, loss = 1.95357922
# Iteration 629, loss = 1.95812660
# Iteration 630, loss = 1.95725062
# Iteration 631, loss = 1.95450233
# Iteration 632, loss = 1.95201628
# Iteration 633, loss = 1.95474497
# Iteration 634, loss = 1.94562796
# Iteration 635, loss = 1.94726233
# Iteration 636, loss = 1.94190837
# Iteration 637, loss = 1.94540344
# Iteration 638, loss = 1.94150864
# Iteration 639, loss = 1.94228410
# Iteration 640, loss = 1.94687097
# Iteration 641, loss = 1.93710043
# Iteration 642, loss = 1.94102874
# Iteration 643, loss = 1.93520664
# Iteration 644, loss = 1.93704564
# Iteration 645, loss = 1.93353412
# Iteration 646, loss = 1.93445652
# Iteration 647, loss = 1.92685683
# Iteration 648, loss = 1.92678084
# Iteration 649, loss = 1.92658908
# Iteration 650, loss = 1.92319511
# Iteration 651, loss = 1.92430863
# Iteration 652, loss = 1.92036382
# Iteration 653, loss = 1.92043734
# Iteration 654, loss = 1.92190048
# Iteration 655, loss = 1.92359041
# Iteration 656, loss = 1.92326953
# Iteration 657, loss = 1.91860889
# Iteration 658, loss = 1.91953176
# Iteration 659, loss = 1.91541882
# Iteration 660, loss = 1.91006462
# Iteration 661, loss = 1.91178000
# Iteration 662, loss = 1.91039989
# Iteration 663, loss = 1.92543802
# Iteration 664, loss = 1.90380140
# Iteration 665, loss = 1.92393537
# Iteration 666, loss = 1.90600734
# Iteration 667, loss = 1.90299604
# Iteration 668, loss = 1.91758024
# Iteration 669, loss = 1.90747956
# Iteration 670, loss = 1.90366060
# Iteration 671, loss = 1.90483329
# Iteration 672, loss = 1.90640385
# Iteration 673, loss = 1.89699882
# Iteration 674, loss = 1.88832184
# Iteration 675, loss = 1.88761070
# Iteration 676, loss = 1.88958532
# Iteration 677, loss = 1.88921048
# Iteration 678, loss = 1.88569724
# Iteration 679, loss = 1.88173189
# Iteration 680, loss = 1.88377441
# Iteration 681, loss = 1.87872223
# Iteration 682, loss = 1.88237131
# Iteration 683, loss = 1.87673152
# Iteration 684, loss = 1.87624762
# Iteration 685, loss = 1.87669237
# Iteration 686, loss = 1.87886022
# Iteration 687, loss = 1.87329688
# Iteration 688, loss = 1.86946699
# Iteration 689, loss = 1.87046367
# Iteration 690, loss = 1.86528133
# Iteration 691, loss = 1.87209377
# Iteration 692, loss = 1.86235014
# Iteration 693, loss = 1.87332008
# Iteration 694, loss = 1.86400228
# Iteration 695, loss = 1.86359472
# Iteration 696, loss = 1.85779945
# Iteration 697, loss = 1.86921186
# Iteration 698, loss = 1.86665178
# Iteration 699, loss = 1.85468924
# Iteration 700, loss = 1.85211066
# Iteration 701, loss = 1.85045926
# Iteration 702, loss = 1.84750214
# Iteration 703, loss = 1.84692264
# Iteration 704, loss = 1.86213403
# Iteration 705, loss = 1.84910083
# Iteration 706, loss = 1.85845070
# Iteration 707, loss = 1.84242075
# Iteration 708, loss = 1.86100894
# Iteration 709, loss = 1.84897596
# Iteration 710, loss = 1.83895751
# Iteration 711, loss = 1.84187329
# Iteration 712, loss = 1.83873235
# Iteration 713, loss = 1.83563067
# Iteration 714, loss = 1.83443713
# Iteration 715, loss = 1.83510811
# Iteration 716, loss = 1.83347216
# Iteration 717, loss = 1.84041898
# Iteration 718, loss = 1.83208263
# Iteration 719, loss = 1.82483716
# Iteration 720, loss = 1.82541532
# Iteration 721, loss = 1.82899053
# Iteration 722, loss = 1.82500370
# Iteration 723, loss = 1.82355429
# Iteration 724, loss = 1.82640234
# Iteration 725, loss = 1.82440504
# Iteration 726, loss = 1.81755378
# Iteration 727, loss = 1.82003066
# Iteration 728, loss = 1.82128986
# Iteration 729, loss = 1.82632486
# Iteration 730, loss = 1.81678325
# Iteration 731, loss = 1.83057941
# Iteration 732, loss = 1.82800669
# Iteration 733, loss = 1.82491472
# Iteration 734, loss = 1.80816209
# Iteration 735, loss = 1.81276560
# Iteration 736, loss = 1.81649231
# Iteration 737, loss = 1.81346399
# Iteration 738, loss = 1.81113238
# Iteration 739, loss = 1.80539678
# Iteration 740, loss = 1.80639938
# Iteration 741, loss = 1.81173309
# Iteration 742, loss = 1.80892035
# Iteration 743, loss = 1.80126085
# Iteration 744, loss = 1.80377966
# Iteration 745, loss = 1.80140609
# Iteration 746, loss = 1.79620510
# Iteration 747, loss = 1.80518755
# Iteration 748, loss = 1.79780287
# Iteration 749, loss = 1.79175927
# Iteration 750, loss = 1.80000075
# Iteration 751, loss = 1.79048924
# Iteration 752, loss = 1.79247883
# Iteration 753, loss = 1.78927084
# Iteration 754, loss = 1.79200946
# Iteration 755, loss = 1.79066794
# Iteration 756, loss = 1.78507513
# Iteration 757, loss = 1.78406122
# Iteration 758, loss = 1.79935974
# Iteration 759, loss = 1.78317872
# Iteration 760, loss = 1.78361340
# Iteration 761, loss = 1.78275934
# Iteration 762, loss = 1.78263337
# Iteration 763, loss = 1.78067536
# Iteration 764, loss = 1.78518709
# Iteration 765, loss = 1.78352369
# Iteration 766, loss = 1.78484606
# Iteration 767, loss = 1.77970840
# Iteration 768, loss = 1.77515717
# Iteration 769, loss = 1.77156416
# Iteration 770, loss = 1.78410249
# Iteration 771, loss = 1.77250624
# Iteration 772, loss = 1.78399797
# Iteration 773, loss = 1.77485691
# Iteration 774, loss = 1.76695754
# Iteration 775, loss = 1.76846096
# Iteration 776, loss = 1.77486634
# Iteration 777, loss = 1.77002807
# Iteration 778, loss = 1.76554275
# Iteration 779, loss = 1.76314413
# Iteration 780, loss = 1.76558013
# Iteration 781, loss = 1.76229595
# Iteration 782, loss = 1.76219418
# Iteration 783, loss = 1.76200247
# Iteration 784, loss = 1.76015715
# Iteration 785, loss = 1.76184681
# Iteration 786, loss = 1.75811844
# Iteration 787, loss = 1.75863887
# Iteration 788, loss = 1.75553574
# Iteration 789, loss = 1.77257465
# Iteration 790, loss = 1.75912016
# Iteration 791, loss = 1.76835873
# Iteration 792, loss = 1.75248412
# Iteration 793, loss = 1.76499496
# Iteration 794, loss = 1.75045871
# Iteration 795, loss = 1.75946800
# Iteration 796, loss = 1.75353697
# Iteration 797, loss = 1.74257973
# Iteration 798, loss = 1.74980542
# Iteration 799, loss = 1.75298467
# Iteration 800, loss = 1.73982085
# Iteration 801, loss = 1.75220984
# Iteration 802, loss = 1.73995358
# Iteration 803, loss = 1.74143299
# Iteration 804, loss = 1.74539155
# Iteration 805, loss = 1.73603560
# Iteration 806, loss = 1.74616910
# Iteration 807, loss = 1.74292693
# Iteration 808, loss = 1.73315261
# Iteration 809, loss = 1.74016043
# Iteration 810, loss = 1.74538297
# Iteration 811, loss = 1.73346662
# Iteration 812, loss = 1.75243281
# Iteration 813, loss = 1.78062982
# Iteration 814, loss = 1.73452854
# Iteration 815, loss = 1.73422767
# Iteration 816, loss = 1.73008975
# Iteration 817, loss = 1.73166928
# Iteration 818, loss = 1.72861277
# Iteration 819, loss = 1.73909151
# Iteration 820, loss = 1.72905164
# Iteration 821, loss = 1.72806369
# Iteration 822, loss = 1.72909457
# Iteration 823, loss = 1.73090570
# Iteration 824, loss = 1.72704710
# Iteration 825, loss = 1.72582538
# Iteration 826, loss = 1.72381848
# Iteration 827, loss = 1.73182035
# Iteration 828, loss = 1.73839118
# Iteration 829, loss = 1.72470239
# Iteration 830, loss = 1.73061453
# Iteration 831, loss = 1.72280568
# Iteration 832, loss = 1.72335210
# Iteration 833, loss = 1.72412227
# Iteration 834, loss = 1.71871588
# Iteration 835, loss = 1.71656024
# Iteration 836, loss = 1.71542576
# Iteration 837, loss = 1.71359176
# Iteration 838, loss = 1.72578908
# Iteration 839, loss = 1.71402184
# Iteration 840, loss = 1.71535812
# Iteration 841, loss = 1.70704879
# Iteration 842, loss = 1.70534043
# Iteration 843, loss = 1.72397253
# Iteration 844, loss = 1.71811884
# Iteration 845, loss = 1.71275767
# Iteration 846, loss = 1.70324846
# Iteration 847, loss = 1.70646936
# Iteration 848, loss = 1.70506940
# Iteration 849, loss = 1.70269113
# Iteration 850, loss = 1.70711229
# Iteration 851, loss = 1.70035069
# Iteration 852, loss = 1.69844792
# Iteration 853, loss = 1.70242060
# Iteration 854, loss = 1.70530020
# Iteration 855, loss = 1.70507764
# Iteration 856, loss = 1.69939242
# Iteration 857, loss = 1.69338132
# Iteration 858, loss = 1.69560493
# Iteration 859, loss = 1.69386386
# Iteration 860, loss = 1.69961563
# Iteration 861, loss = 1.70663701
# Iteration 862, loss = 1.69575398
# Iteration 863, loss = 1.69228606
# Iteration 864, loss = 1.69287821
# Iteration 865, loss = 1.69187370
# Iteration 866, loss = 1.68882121
# Iteration 867, loss = 1.68763605
# Iteration 868, loss = 1.69421091
# Iteration 869, loss = 1.69526908
# Iteration 870, loss = 1.68989720
# Iteration 871, loss = 1.68401965
# Iteration 872, loss = 1.68788496
# Iteration 873, loss = 1.68359060
# Iteration 874, loss = 1.68534243
# Iteration 875, loss = 1.67748867
# Iteration 876, loss = 1.69184749
# Iteration 877, loss = 1.68448884
# Iteration 878, loss = 1.68513772
# Iteration 879, loss = 1.68070294
# Iteration 880, loss = 1.67899627
# Iteration 881, loss = 1.68202455
# Iteration 882, loss = 1.67756472
# Iteration 883, loss = 1.68166596
# Iteration 884, loss = 1.67609740
# Iteration 885, loss = 1.67916963
# Iteration 886, loss = 1.68200169
# Iteration 887, loss = 1.67210843
# Iteration 888, loss = 1.67024605
# Iteration 889, loss = 1.67109308
# Iteration 890, loss = 1.67943588
# Iteration 891, loss = 1.67096333
# Iteration 892, loss = 1.67895990
# Iteration 893, loss = 1.66622904
# Iteration 894, loss = 1.67708185
# Iteration 895, loss = 1.67233837
# Iteration 896, loss = 1.68833126
# Iteration 897, loss = 1.66473275
# Iteration 898, loss = 1.66810111
# Iteration 899, loss = 1.66553912
# Iteration 900, loss = 1.66623653
# Iteration 901, loss = 1.66181380
# Iteration 902, loss = 1.65962592
# Iteration 903, loss = 1.68139792
# Iteration 904, loss = 1.67438593
# Iteration 905, loss = 1.65773125
# Iteration 906, loss = 1.65948784
# Iteration 907, loss = 1.66107909
# Iteration 908, loss = 1.65180464
# Iteration 909, loss = 1.66431471
# Iteration 910, loss = 1.65999582
# Iteration 911, loss = 1.65730431
# Iteration 912, loss = 1.65372511
# Iteration 913, loss = 1.66976657
# Iteration 914, loss = 1.67025268
# Iteration 915, loss = 1.65550134
# Iteration 916, loss = 1.64949719
# Iteration 917, loss = 1.64140399
# Iteration 918, loss = 1.66079027
# Iteration 919, loss = 1.64794531
# Iteration 920, loss = 1.63989643
# Iteration 921, loss = 1.64919070
# Iteration 922, loss = 1.64378628
# Iteration 923, loss = 1.64187981
# Iteration 924, loss = 1.64046638
# Iteration 925, loss = 1.64623221
# Iteration 926, loss = 1.63629510
# Iteration 927, loss = 1.64393822
# Iteration 928, loss = 1.63755706
# Iteration 929, loss = 1.64977076
# Iteration 930, loss = 1.64070116
# Iteration 931, loss = 1.64634203
# Iteration 932, loss = 1.63027163
# Iteration 933, loss = 1.64087907
# Iteration 934, loss = 1.64619363
# Iteration 935, loss = 1.62723552
# Iteration 936, loss = 1.64103480
# Iteration 937, loss = 1.63661638
# Iteration 938, loss = 1.63065621
# Iteration 939, loss = 1.65351916
# Iteration 940, loss = 1.64179807
# Iteration 941, loss = 1.64101168
# Iteration 942, loss = 1.62903482
# Iteration 943, loss = 1.62964098
# Iteration 944, loss = 1.62510184
# Iteration 945, loss = 1.62674354
# Iteration 946, loss = 1.62762060
# Iteration 947, loss = 1.62998209
# Iteration 948, loss = 1.62377224
# Iteration 949, loss = 1.62260304
# Iteration 950, loss = 1.62495235
# Iteration 951, loss = 1.62353190
# Iteration 952, loss = 1.61720953
# Iteration 953, loss = 1.62023660
# Iteration 954, loss = 1.61946747
# Iteration 955, loss = 1.62437973
# Iteration 956, loss = 1.62142613
# Iteration 957, loss = 1.61252168
# Iteration 958, loss = 1.61574371
# Iteration 959, loss = 1.62850433
# Iteration 960, loss = 1.61900021
# Iteration 961, loss = 1.61286457
# Iteration 962, loss = 1.61853666
# Iteration 963, loss = 1.61034077
# Iteration 964, loss = 1.61575115
# Iteration 965, loss = 1.61087990
# Iteration 966, loss = 1.61179402
# Iteration 967, loss = 1.61594216
# Iteration 968, loss = 1.61068087
# Iteration 969, loss = 1.61300509
# Iteration 970, loss = 1.61717902
# Iteration 971, loss = 1.61424455
# Iteration 972, loss = 1.61659695
# Iteration 973, loss = 1.60453223
# Iteration 974, loss = 1.61130442
# Iteration 975, loss = 1.60913399
# Iteration 976, loss = 1.60465635
# Iteration 977, loss = 1.60649834
# Iteration 978, loss = 1.60357414
# Iteration 979, loss = 1.59999272
# Iteration 980, loss = 1.60236408
# Iteration 981, loss = 1.59966124
# Iteration 982, loss = 1.59710291
# Iteration 983, loss = 1.60166173
# Iteration 984, loss = 1.60150593
# Iteration 985, loss = 1.59394810
# Iteration 986, loss = 1.60967226
# Iteration 987, loss = 1.61432372
# Iteration 988, loss = 1.62956127
# Iteration 989, loss = 1.60915134
# Iteration 990, loss = 1.59785293
# Iteration 991, loss = 1.59939800
# Iteration 992, loss = 1.59310846
# Iteration 993, loss = 1.59494010
# Iteration 994, loss = 1.60353106
# Iteration 995, loss = 1.60459798
# Iteration 996, loss = 1.59167524
# Iteration 997, loss = 1.58804453
# Iteration 998, loss = 1.59570284
# Iteration 999, loss = 1.59145080
# Iteration 1000, loss = 1.58997948
# Iteration 1001, loss = 1.59685034
# Iteration 1002, loss = 1.58702494
# Iteration 1003, loss = 1.58619738
# Iteration 1004, loss = 1.58332834
# Iteration 1005, loss = 1.58575168
# Iteration 1006, loss = 1.58836158
# Iteration 1007, loss = 1.59318917
# Iteration 1008, loss = 1.58126053
# Iteration 1009, loss = 1.58284025
# Iteration 1010, loss = 1.58495864
# Iteration 1011, loss = 1.58728560
# Iteration 1012, loss = 1.59265594
# Iteration 1013, loss = 1.57980632
# Iteration 1014, loss = 1.58127156
# Iteration 1015, loss = 1.58395721
# Iteration 1016, loss = 1.57712065
# Iteration 1017, loss = 1.57496158
# Iteration 1018, loss = 1.58539603
# Iteration 1019, loss = 1.57510213
# Iteration 1020, loss = 1.57311926
# Iteration 1021, loss = 1.57198783
# Iteration 1022, loss = 1.57366904
# Iteration 1023, loss = 1.57365815
# Iteration 1024, loss = 1.57264102
# Iteration 1025, loss = 1.56945980
# Iteration 1026, loss = 1.56803977
# Iteration 1027, loss = 1.56936351
# Iteration 1028, loss = 1.56855061
# Iteration 1029, loss = 1.56305306
# Iteration 1030, loss = 1.57012028
# Iteration 1031, loss = 1.56685571
# Iteration 1032, loss = 1.56528737
# Iteration 1033, loss = 1.56655772
# Iteration 1034, loss = 1.55913406
# Iteration 1035, loss = 1.56004414
# Iteration 1036, loss = 1.56213295
# Iteration 1037, loss = 1.56222022
# Iteration 1038, loss = 1.55163085
# Iteration 1039, loss = 1.56453729
# Iteration 1040, loss = 1.55600343
# Iteration 1041, loss = 1.57010128
# Iteration 1042, loss = 1.56164599
# Iteration 1043, loss = 1.57662791
# Iteration 1044, loss = 1.56124679
# Iteration 1045, loss = 1.55965005
# Iteration 1046, loss = 1.55597475
# Iteration 1047, loss = 1.55189073
# Iteration 1048, loss = 1.55344840
# Iteration 1049, loss = 1.55006703
# Iteration 1050, loss = 1.55805160
# Iteration 1051, loss = 1.55606254
# Iteration 1052, loss = 1.55601131
# Iteration 1053, loss = 1.55130734
# Iteration 1054, loss = 1.55164095
# Iteration 1055, loss = 1.54897751
# Iteration 1056, loss = 1.55116303
# Iteration 1057, loss = 1.55627402
# Iteration 1058, loss = 1.55100219
# Iteration 1059, loss = 1.54572615
# Iteration 1060, loss = 1.53954548
# Iteration 1061, loss = 1.54514719
# Iteration 1062, loss = 1.54271954
# Iteration 1063, loss = 1.54113626
# Iteration 1064, loss = 1.54085259
# Iteration 1065, loss = 1.56982782
# Iteration 1066, loss = 1.56195047
# Iteration 1067, loss = 1.53753445
# Iteration 1068, loss = 1.54631546
# Iteration 1069, loss = 1.54254390
# Iteration 1070, loss = 1.56088610
# Iteration 1071, loss = 1.54546571
# Iteration 1072, loss = 1.56425063
# Iteration 1073, loss = 1.55521154
# Iteration 1074, loss = 1.53404068
# Iteration 1075, loss = 1.54323985
# Iteration 1076, loss = 1.54495028
# Iteration 1077, loss = 1.53089128
# Iteration 1078, loss = 1.56223699
# Iteration 1079, loss = 1.54566588
# Iteration 1080, loss = 1.54675990
# Iteration 1081, loss = 1.52781440
# Iteration 1082, loss = 1.54454963
# Iteration 1083, loss = 1.52067974
# Iteration 1084, loss = 1.55137090
# Iteration 1085, loss = 1.53139260
# Iteration 1086, loss = 1.53359763
# Iteration 1087, loss = 1.53614365
# Iteration 1088, loss = 1.52475626
# Iteration 1089, loss = 1.52539757
# Iteration 1090, loss = 1.52624371
# Iteration 1091, loss = 1.52167344
# Iteration 1092, loss = 1.52939800
# Iteration 1093, loss = 1.52472180
# Iteration 1094, loss = 1.52130522
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(hidden_layer_sizes=[100, 10, 1], max_iter=10000, verbose=2)

# %%
mean_squared_error(y_val, mlp_reg.predict(X_val_dca))
# Out:
# 1.3279643319544534

# %%
mean_squared_error(y_train, mlp_reg.predict(X_train_dca))
# Out:
# 3.035461411959267

# %%
predict_plot(y_train, mlp_reg.predict(X_train_dca))
# Out:
# C:\Users\spect\AppData\Local\Temp\ipykernel_20984\1171456457.py:16: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)
# C:\Users\spect\AppData\Local\Temp\ipykernel_20984\1171456457.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cbar.ax.set_yticklabels(['0','','','',"",'1'])

# %%
predict_plot(y_val, mlp_reg.predict(X_val_dca))
# Out:
# C:\Users\spect\AppData\Local\Temp\ipykernel_20984\1171456457.py:16: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)
# C:\Users\spect\AppData\Local\Temp\ipykernel_20984\1171456457.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cbar.ax.set_yticklabels(['0','','','',"",'1'])
